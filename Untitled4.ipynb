# %% [markdown]
# <a href="https://colab.research.google.com/github/samukablack2021-cyber/ProgramacaoDomJoao/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa recebe dois numeros e diz qual e menor e qual e maior
print("escolha dois umeros aleatorios")

float(input("Digite o primeiro numero"))
float(input("digite o segundo numero"))

if num1 > num2:
  print("o numero maior e o numero ")
  print("o numero maior e o numero ")
# Out:
#   File "/tmp/ipython-input-2364337430.py", line 8
#     print("o numero maior e o numero" {num1})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
