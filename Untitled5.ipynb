# %% [markdown]
# <a href="https://colab.research.google.com/github/samukablack2021-cyber/ProgramacaoDomJoao/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
print("Seja bem vindo!!")
print("Nesse aplicativo você ira descobrir seu peso em planetas dos sistema solar!!")

pesoJogador = float(input("Digite o seu peso"))

print(f"Netuno:{pesoJogador * 1.14:.2f} kg")
print(f"Urano: {pesoJogador * 0.88:.2f}kg")
print(f"Saturno: {pesoJogador * 1.07:.2f}kg")
print(f"Jupiter: {pesoJogador * 2.53:>2f}kg")
print(f"Marte:{pesoJogador * 0.38:.2f}kg ")
print(f"Venus: {pesoJogador * 0.91:.2f}kg")
print(f"Mercurio: {pesoJogador * 0.38:.2f}kg")
print(f"Plutao: {pesoJogador * 4.7:.2f}kg")
# Out:
# Seja bem vindo!!
# Nesse aplicativo você ira descobrir seu peso em planetas dos sistema solar!!
# Digite o seu peso48
# Netuno:54.72 kg
# Urano: 42.24kg
# Saturno: 51.36kg
# Jupiter: 121.440000kg
# Marte:18.24kg
# Venus: 43.68kg
# Mercurio: 18.24kg
# Plutao: 225.60kg
